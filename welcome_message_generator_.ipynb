# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharika-k/localrepo/blob/main/welcome_message_generator_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# welcome message generator
 #step1: ask for user details
name = input("What's your name?")
hobby = input("What's your favorite hobby?")
color = input("what's your favourite color?")
name = name.upper()
hobby =hobby.lower()
# step2: GENERATE A PERSONALIZED WELCOME MESSAGE
print("\n--- welcome Message------")
print(f"Hello,{name}!")
print(f"Welcome to the coding world.")
print(f" lets have fun doing coding.")
print(f" It's great to know that you love {hobby}.")
print(f" It's great to know that your favourite {color}")
print(f"get ready to build something amazing today,")
# Out:
# What's your name?sriharika
# What's your favorite hobby?coding
# what's your favourite color?black
#
# --- welcome Message------
# Hello,SRIHARIKA!
# Welcome to the coding world.
#  lets have fun doing coding.
#  It's great to know that you love coding.
#  It's great to know that your favourite black
# get ready to build something amazing today,
